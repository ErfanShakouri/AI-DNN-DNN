# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt

# %%
#load dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
print("x_train.shape",x_train.shape)
print("y_train.shape",y_train.shape)
print("x_test.shape",x_test.shape)
print("y_test.shape",y_test.shape)
# Out:
# x_train.shape (60000, 28, 28)
# y_train.shape (60000,)
# x_test.shape (10000, 28, 28)
# y_test.shape (10000,)

# %%
#Normalized data
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
init = keras.initializers.VarianceScaling(scale=2., mode='fan_avg')

# %%
#define model
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28,28]),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(100, kernel_initializer = init,  use_bias = False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("elu"),
    keras.layers.Dense(75, use_bias=False),
    keras.layers.BatchNormalization(),
    keras.layers.LeakyReLU(alpha = 0.3),
    keras.layers.Dense(10, activation = "softmax"),
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 784)                 │           3,136 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 100)                 │          78,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 100)                 │             400 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 75)                  │           7,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 75)                  │             300 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 75)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 10)                  │             760 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 90,496 (353.50 KB)
#  Trainable params: 88,578 (346.01 KB)
#  Non-trainable params: 1,918 (7.49 KB)

# %% [markdown]
# # Hyperparameters (Power lr)

# %%
sgd = keras.optimizers.SGD(decay = 1e-3)
model.compile(loss = "sparse_categorical_crossentropy",
              optimizer = sgd,
              metrics = ["accuracy"])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %%
run_model1 = model.fit(x_train, y_train, epochs = 40, validation_split = 0.15)
# Out:
# Epoch 1/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7080 - loss: 0.9035 - val_accuracy: 0.8239 - val_loss: 0.4954
# Epoch 2/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8276 - loss: 0.5061 - val_accuracy: 0.8437 - val_loss: 0.4407
# Epoch 3/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8392 - loss: 0.4556 - val_accuracy: 0.8489 - val_loss: 0.4256
# Epoch 4/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8500 - loss: 0.4277 - val_accuracy: 0.8584 - val_loss: 0.3978
# Epoch 5/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8577 - loss: 0.4045 - val_accuracy: 0.8607 - val_loss: 0.3891
# Epoch 6/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8570 - loss: 0.3986 - val_accuracy: 0.8629 - val_loss: 0.3771
# Epoch 7/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8655 - loss: 0.3814 - val_accuracy: 0.8652 - val_loss: 0.3719
# Epoch 8/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8663 - loss: 0.3739 - val_accuracy: 0.8717 - val_loss: 0.3629
# Epoch 9/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8707 - loss: 0.3646 - val_accuracy: 0.8724 - val_loss: 0.3579
# Epoch 10/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8755 - loss: 0.3462 - val_accuracy: 0.8751 - val_loss: 0.3566
# Epoch 11/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8779 - loss: 0.3420 - val_accuracy: 0.8762 - val_loss: 0.3491
# Epoch 12/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8820 - loss: 0.3352 - val_accuracy: 0.8738 - val_loss: 0.3516
# Epoch 13/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8864 - loss: 0.3192 - val_accuracy: 0.8760 - val_loss: 0.3477
# Epoch 14/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8814 - loss: 0.3224 - val_accuracy: 0.8773 - val_loss: 0.3439
# Epoch 15/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8886 - loss: 0.3145 - val_accuracy: 0.8800 - val_loss: 0.3375
# Epoch 16/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8894 - loss: 0.3070 - val_accuracy: 0.8782 - val_loss: 0.3429
# Epoch 17/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.8881 - loss: 0.3046 - val_accuracy: 0.8799 - val_loss: 0.3372
# Epoch 18/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8913 - loss: 0.2998 - val_accuracy: 0.8793 - val_loss: 0.3367
# Epoch 19/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8905 - loss: 0.2953 - val_accuracy: 0.8807 - val_loss: 0.3343
# Epoch 20/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8937 - loss: 0.2943 - val_accuracy: 0.8813 - val_loss: 0.3383
# Epoch 21/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8964 - loss: 0.2844 - val_accuracy: 0.8821 - val_loss: 0.3307
# Epoch 22/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8981 - loss: 0.2790 - val_accuracy: 0.8800 - val_loss: 0.3395
# Epoch 23/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8997 - loss: 0.2804 - val_accuracy: 0.8822 - val_loss: 0.3301
# Epoch 24/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8991 - loss: 0.2781 - val_accuracy: 0.8798 - val_loss: 0.3311
# Epoch 25/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9025 - loss: 0.2669 - val_accuracy: 0.8836 - val_loss: 0.3337
# Epoch 26/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9026 - loss: 0.2683 - val_accuracy: 0.8842 - val_loss: 0.3288
# Epoch 27/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9054 - loss: 0.2599 - val_accuracy: 0.8822 - val_loss: 0.3298
# Epoch 28/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9070 - loss: 0.2572 - val_accuracy: 0.8832 - val_loss: 0.3279
# Epoch 29/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9076 - loss: 0.2550 - val_accuracy: 0.8851 - val_loss: 0.3274
# Epoch 30/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9079 - loss: 0.2518 - val_accuracy: 0.8843 - val_loss: 0.3288
# Epoch 31/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9111 - loss: 0.2476 - val_accuracy: 0.8864 - val_loss: 0.3313
# Epoch 32/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9131 - loss: 0.2397 - val_accuracy: 0.8841 - val_loss: 0.3282
# Epoch 33/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9088 - loss: 0.2469 - val_accuracy: 0.8848 - val_loss: 0.3308
# Epoch 34/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9134 - loss: 0.2382 - val_accuracy: 0.8869 - val_loss: 0.3248
# Epoch 35/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9163 - loss: 0.2328 - val_accuracy: 0.8888 - val_loss: 0.3225
# Epoch 36/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9157 - loss: 0.2339 - val_accuracy: 0.8838 - val_loss: 0.3336
# Epoch 37/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9166 - loss: 0.2277 - val_accuracy: 0.8861 - val_loss: 0.3293
# Epoch 38/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9170 - loss: 0.2311 - val_accuracy: 0.8870 - val_loss: 0.3261
# Epoch 39/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9156 - loss: 0.2296 - val_accuracy: 0.8858 - val_loss: 0.3294
# Epoch 40/40
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9192 - loss: 0.2240 - val_accuracy: 0.8832 - val_loss: 0.3319

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))  # Adjust figsize as needed
ax1.plot(run_model1.history["accuracy"], label="train_accuracy", lw = 3, linestyle ='-')
ax1.plot(run_model1.history["val_accuracy"], label="val_accuracy", lw = 3, linestyle ='--')
ax1.set_ylabel('Accuracy (%)', fontsize=15)
ax1.set_xlabel('Epoch', fontsize=15)
ax1.legend()
ax1.tick_params(axis='both', which='major', labelsize=15)
ax2.plot(run_model1.history["loss"], label="train_loss", lw = 3, linestyle ='-')
ax2.plot(run_model1.history["val_loss"], label="val_loss", lw = 3, linestyle ='--')
ax2.set_ylabel('Loss ', fontsize=15)
ax2.set_xlabel('Epoch', fontsize=15)
ax2.legend()
ax2.tick_params(axis='both', which='major', labelsize=15)
plt.tight_layout()
